# %% [markdown]
# 1a. write a python pgm to create two empty classes, student and marks. now create some instances and check whether they are instances of the said classes or not. Also, check whether the said classes are subclasses of the built-in object class or not.

# %%
#1a
class student:
  pass
class marks:
  pass
s=student()
m=marks()
print(f"Is s instance of student? {isinstance(s,student)}")
print(f"Is s instance of marks? {isinstance(s,marks)}")
print(f"Is m instance of student? {isinstance(m,student)}")
print(f"Is m instance of marks? {isinstance(m,marks)}")
print("Check whether classes are subclasses of built in objects:")
print(issubclass(student,object))
print(issubclass(marks,object))
# Out:
# Is s instance of student? True
# Is s instance of marks? False
# Is m instance of student? False
# Is m instance of marks? True
# Check whether classes are subclasses of built in objects:
# True
# True

# %% [markdown]
# 1b. Perform addition of two complex numbers using class COMPLEX. COMPLEX has two class variables real_part and img_part. Constructors assigns values for the respective variables. Create three objects C1,C2 and C3, where C3 is the result of adding C1 and C2.

# %%
#1b
class COMPLEX:
    def __init__(self, real_part, img_part):
        self.real_part = real_part
        self.img_part = img_part
    def add(self, other):
        res_real = self.real_part + other.real_part
        res_img = self.img_part + other.img_part
        print(f"({self.real_part} + i{self.img_part}) + ({other.real_part} + i{other.img_part}) = {res_real} + i{res_img}")
a = COMPLEX(2, 3)
b = COMPLEX(4, 2)
a.add(b)
# Out:
# (2 + i3) + (4 + i2) = 6 + i5

# %% [markdown]
# 2a. define a class called songs, it will show the lyrics of a song. its init method should have two arguments self and lyrics. lyrics is a list. inside your class create a method called sing_me_a_song that prints each element of lyrics on his own line. define a variable happy_bday=song(["may god bless you,","have a sunshine on you,","happy birthday to you!"]) call the sing_me_a_song method on this variable.

# %%
class songs:
  def __init__(self,lyrics):
    self.lyrics=lyrics
  def sing_me_a_song(self):
    for i in self.lyrics:
      print(i)
happy_bday=songs(["may god bless you,","have a sunshine on you,","happy birthday to you!"])
happy_bday.sing_me_a_song()
# Out:
# may god bless you,
# have a sunshine on you,
# happy birthday to you!

# %% [markdown]
# 2b. class dog attributes:name,size,breed default=unknown, dob in ddmmyyyy format default=unknown methods: bark- this should get the dog to bark, print woof get_name= return the dog's name set_name-allow the user to set an alphabetical name between 2 and 30 characters.convert name to title case before setting dog_years-calculate dog's age in dog years(1 year=7 dog years)

# %%
class dog:
  def __init__(self,name,size,breed='unknown',dob='unknown'):
    self.name=name
    self.size=size
    self.breed=breed
    self.dob=dob
  def bark(self):
    print("WOOF!")
  def get_name(self):
    return self.name
  def set_name(self,new):
    if len(new)>2 and len(new)<30:
      self.name=new.title()
    else:
      print("Length does not satisfy")
    return self.name
  def dog_years(self):
    if self.dob!='unknown':
      yob=self.dob[4:]
      year=int(yob)
      cur_year=2024
      print(year)
      age=(cur_year-year)*7
      print(age)
    else:
      print("DOB is unknown")
d=dog('abc',32,'pomeranian','01012018')
d.bark()
print(d.get_name())
print(d.set_name('bad'))
d.dog_years()
# Out:
# WOOF!
# abc
# Bad
# 2018
# 42

# %% [markdown]
# 3a. Create a employee class by defining employee attributes such as name and salary as an instance variable and implementing behaviour using work() and show() instance methods. make salary as private variable.

# %%
class employee:
  def __init__(self,name,salary):
    self.name=name
    self.__salary=salary
  def work(self):
    print(f"{self.name} is working")
  def getsal(self):
    return self.__salary
  def show(self):
    print(f"{self.name}'s Salary:")
    print(self.getsal())
a=employee('abc',1200)
a.work()
a.show()
# Out:
# abc is working
# abc's Salary:
# 1200

# %% [markdown]
# 3b. create a class called as credit, make the limit variable completely private to the outside of the class and balance should be Accessible outside the class  but not modifiable since we don't want external code to arbitrarily modify the card balance. to achieve this make a get balance() field public however balance
# can only be modified via withdraw and deposit methods that have safeguards in check place.

# %%
class credit:
  def __init__(self,limit):
    self.__limit=limit
    self.__bal=0
  def getbalance(self):
    return(f"Balance:{self.__bal}")
  def withdraw(self,amt):
    if amt>0:
      if amt>self.__bal:
        print("Failed")
      else:
        self.__bal=self.__bal-amt
        print(f"Successful! New Balance={self.__bal}")
    else:
      print("Failed")
  def deposit(self,amt):
    if amt>0:
        self.__bal=self.__bal+amt
        print(f"Successful! New Balance={self.__bal}")
    else:
      print("Failed")
obj=credit(1000)
obj.deposit(500)
obj.withdraw(100)
print(obj.getbalance())
# Out:
# Successful! New Balance=500
# Successful! New Balance=400
# Balance:400

# %% [markdown]
# 4. import the abc module to create the abstract base class. create the class that inherits the abc class and define an abstract method named mileage().
# inherit the base class from three different subclasses and implement the abstract method differently. create the objects to call the abstract method

# %%
from abc import ABC, abstractmethod
class car(ABC):
    @abstractmethod
    def mileage(self):
        pass
class sedan(car):
    def mileage(self):
        print("Sedan mileage: 25 miles per gallon")
class SUV(car):
    def mileage(self):
        print("SUV mileage: 20 miles per gallon")
class ec(car):
    def mileage(self):
        print("Electric car mileage: 100 miles per charge")
h1=sedan()
h1.mileage()
n1=SUV()
n1.mileage()
a1=ec()
a1.mileage()
# Out:
# Sedan mileage: 25 miles per gallon
# SUV mileage: 20 miles per gallon
# Electric car mileage: 100 miles per charge

# %% [markdown]
# 5a. create two parent classes person and company respectively. create one child class called employee which inherits from person and company to implement multiple inheritance.

# %%
class person:
  def __init__(self,name,age):
    self.name=name
    self.age=age
  def displayperson(self):
    print(f"Name:{self.name} Age:{self.age}")
class company:
  def __init__(self,years):
    self.years=years
  def displaycompany(self):
    print(f"Number of Years:{self.years}")
class employee(person,company):
  def __init__(self,name,age,years,empid):
    person.__init__(self,name,age)
    company.__init__(self,years)
    self.empid=empid
  def displayemp(self):
    person.displayperson(self)
    company.displaycompany(self)
    print(f"Empid:{self.empid}")
obj=employee("abc",45,10,123)
obj.displayemp()
# Out:
# Name:abc Age:45
# Number of Years:10
# Empid:123

# %% [markdown]
# 5b. to support multilevel inheritance three classes named vehicle, car and sportscar need to be created. vehicle is superclass, car is a child of vehicle and sportscar is child of car.

# %%
class Vehicle:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

    def display_info(self):
        print(f"Vehicle: {self.brand} {self.model}")


class Car(Vehicle):
    def __init__(self, brand, model, num_doors):
        super().__init__(brand, model)
        self.num_doors = num_doors

    def display_info(self):
        super().display_info()
        print(f"Number of Doors: {self.num_doors}")


class SportsCar(Car):
    def __init__(self, brand, model, num_doors, top_speed):
        super().__init__(brand, model, num_doors)
        self.top_speed = top_speed

    def display_info(self):
        super().display_info()
        print(f"Top Speed: {self.top_speed} mph")

sports_car = SportsCar("Ferrari", "488 GTB",2,205)
sports_car.display_info()
# Out:
# Vehicle: Ferrari 488 GTB
# Number of Doors: 2
# Top Speed: 205 mph
